# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:38, 822KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6769 0.0355 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6088 0.0289 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5424 0.0284 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6017 0.0282 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5012 0.0284 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5608 0.0283 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5655 0.0284 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5215 0.0283 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4606 0.0284 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4187 0.0282 sec/batch
# Nearest to may: codes, wheel, macrophages, argentinean, lovin, displacement, drugs, memes,
# Nearest to in: ralph, restrain, susceptible, airbus, grocer, cheat, heathens, interprets,
# Nearest to i: defaced, sociolinguistic, forecasts, manifestos, debt, perry, turgot, shafts,
# Nearest to known: augustus, wagoner, whispers, gaming, currently, overheard, macias, procuring,
# Nearest to often: cobol, logische, pinker, chemicals, quantico, coffea, dunlop, analyze,
# Nearest to can: excavated, david, cells, courtenay, okina, osmium, smitten, caravaggio,
# Nearest to other: popperian, mineralogy, harwich, duplicates, inner, detached, barbarous, latifolia,
# Nearest to not: agonal, grief, dye, fredrick, thirties, invitations, enthroned, mani,
# Nearest to defense: equids, safavid, parallel, oncology, olives, going, hearse, fungi,
# Nearest to derived: cellulose, ede, hagerstown, prosthesis, copernican, governors, faxes, humourous,
# Nearest to hit: chayefsky, image, rained, ajiva, kano, laundry, pedersen, condensed,
# Nearest to liberal: vertebra, doraemon, susceptible, eduke, circulating, semele, sutton, alves,
# Nearest to square: deutschen, better, leaven, trouble, labiodental, aor, nk, uses,
# Nearest to heavy: sato, lhs, venter, frictional, agust, chuppah, mannerisms, shutting,
# Nearest to bible: logie, depravity, teleplay, rubric, belfast, circassians, mrnas, curdling,
# Nearest to gold: enrico, seeing, frauds, gibraltarians, lz, cdc, favoured, humanists,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4898 0.0295 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3743 0.0282 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2965 0.0283 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2455 0.0282 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1749 0.0282 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1699 0.0285 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0822 0.0283 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0384 0.0282 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9878 0.0282 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9933 0.0283 sec/batch
# Nearest to may: codes, wheel, drugs, zone, displacement, characterised, model, estonia,
# Nearest to in: ralph, susceptible, restrain, russian, central, greek, complex, airbus,
# Nearest to i: debt, perry, defaced, sociolinguistic, longer, reviews, color, surgeon,
# Nearest to known: currently, sea, gaming, well, passion, technological, literary, friends,
# Nearest to often: cobol, chemicals, consist, pinker, logische, analyze, deny, coffea,
# Nearest to can: cells, excavated, whether, david, earth, caravaggio, slow, spent,
# Nearest to other: popperian, inner, mineralogy, duplicates, detached, harwich, rare, homosexuals,
# Nearest to not: dye, agonal, grief, confuse, option, penguin, partly, displays,
# Nearest to defense: equids, parallel, going, what, soil, oncology, fungi, doctoral,
# Nearest to derived: winds, cellulose, telstra, faxes, smoked, hagerstown, soil, prosthesis,
# Nearest to hit: image, structures, ajiva, condensed, rained, chayefsky, conspiracies, kano,
# Nearest to liberal: susceptible, vertebra, eduke, doraemon, circulating, partners, semele, rigid,
# Nearest to square: better, trouble, deutschen, uses, leaven, breaks, nk, scholars,
# Nearest to heavy: sato, frictional, venter, chuppah, mannerisms, advocating, lhs, playoff,
# Nearest to bible: logie, depravity, dependent, exterminate, staged, visible, teleplay, eclectic,
# Nearest to gold: seeing, enrico, frauds, advent, favoured, cdc, lz, harm,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9358 0.0294 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8823 0.0285 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8776 0.0287 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8691 0.0285 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8253 0.0282 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8362 0.0283 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8011 0.0282 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7890 0.0283 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7946 0.0284 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7890 0.0283 sec/batch
# Nearest to may: codes, vocalist, wheel, characterised, model, guildhall, drugs, argentinean,
# Nearest to in: greek, ralph, restrain, interprets, cheat, susceptible, russian, sleeve,
# Nearest to i: debt, defaced, sociolinguistic, perry, reviews, surgeon, color, forecasts,
# Nearest to known: sea, gaming, currently, technological, augustus, well, overheard, procuring,
# Nearest to often: chemicals, cobol, analyze, deny, pinker, logische, resume, consist,
# Nearest to can: cells, excavated, whether, caravaggio, earth, oriental, cartridges, courtenay,
# Nearest to other: popperian, mineralogy, inner, harwich, troubles, duplicates, firearms, detached,
# Nearest to not: dye, agonal, grief, enthroned, mani, confuse, clinch, option,
# Nearest to defense: equids, going, parallel, what, fungi, doctoral, soil, oncology,
# Nearest to derived: winds, faxes, telstra, cellulose, smoked, soil, governors, prosthesis,
# Nearest to hit: image, structures, condensed, ajiva, pedersen, rained, kano, conspiracies,
# Nearest to liberal: susceptible, eduke, payments, vertebra, circulating, partners, doraemon, overseen,
# Nearest to square: better, trouble, deutschen, uses, leaven, proven, nk, breaks,
# Nearest to heavy: sato, frictional, mannerisms, advocating, chuppah, venter, tarrasch, injunction,
# Nearest to bible: logie, eclectic, depravity, teleplay, exterminate, annotations, dependent, circassians,
# Nearest to gold: enrico, seeing, frauds, advent, favoured, harm, cdc, gibraltarians,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7999 0.0294 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7515 0.0284 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7008 0.0284 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7196 0.0280 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7289 0.0285 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7194 0.0284 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7091 0.0288 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7311 0.0286 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7014 0.0282 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6555 0.0282 sec/batch
# Nearest to may: codes, vocalist, lovin, delicacy, memes, characterised, adorned, declared,
# Nearest to in: restrain, interprets, greek, cheat, ralph, russian, accord, grocer,
# Nearest to i: sociolinguistic, defaced, collier, debt, manifestos, reviews, militia, longer,
# Nearest to known: augustus, overheard, sea, gaming, filter, well, currently, parnell,
# Nearest to often: cobol, chemicals, analyze, deny, logische, pinker, decimated, resume,
# Nearest to can: cells, excavated, caravaggio, cartridges, ink, whether, shreveport, earth,
# Nearest to other: popperian, mineralogy, harwich, troubles, duplicates, inner, disused, firearms,
# Nearest to not: dye, agonal, grief, enthroned, mani, clinch, reproductive, brandon,
# Nearest to defense: equids, safavid, going, parallel, what, doctoral, olives, fungi,
# Nearest to derived: faxes, telstra, winds, cellulose, smoked, prosthesis, hagerstown, governors,
# Nearest to hit: image, condensed, ajiva, rained, kano, pedersen, conspiracies, structures,
# Nearest to liberal: susceptible, payments, vertebra, eduke, partners, alves, flourished, overseen,
# Nearest to square: better, trouble, leaven, deutschen, nk, tm, uses, schematic,
# Nearest to heavy: sato, venter, chuppah, mannerisms, surfaces, frictional, advocating, tarrasch,
# Nearest to bible: logie, depravity, eclectic, exterminate, teleplay, circassians, sever, emulating,
# Nearest to gold: enrico, seeing, frauds, collaboratively, advent, favoured, harm, gib,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6606 0.0294 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6597 0.0282 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6183 0.0284 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6251 0.0283 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6447 0.0285 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6313 0.0284 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6096 0.0209 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5391 0.0285 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5168 0.0283 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5233 0.0285 sec/batch
# Nearest to may: delicacy, codes, adorned, vocalist, memes, stencils, displacement, wheel,
# Nearest to in: restrain, accord, interprets, grocer, greek, intentions, heathens, fucking,
# Nearest to i: sociolinguistic, defaced, collier, reviews, manifestos, bowling, canseco, itch,
# Nearest to known: overheard, sea, currently, parnell, augustus, fluorescent, well, procuring,
# Nearest to often: cobol, analyze, chemicals, coffea, logische, deny, normalised, decimated,
# Nearest to can: cells, earth, whether, ink, caravaggio, very, cartridges, excavated,
# Nearest to other: popperian, harwich, mineralogy, duplicates, disused, inner, troubles, firearms,
# Nearest to not: dye, agonal, enthroned, mani, grief, abbr, clinch, might,
# Nearest to defense: equids, safavid, going, olives, oncology, doctoral, overruled, parallel,
# Nearest to derived: faxes, humourous, smoked, winds, telstra, politicized, hagerstown, copernican,
# Nearest to hit: image, rained, kano, condensed, ajiva, pedersen, chayefsky, viola,
# Nearest to liberal: vertebra, eduke, payments, election, overseen, alves, susceptible, partners,
# Nearest to square: better, trouble, tm, leaven, nk, deutschen, schematic, dalhousie,
# Nearest to heavy: sato, venter, chuppah, shutting, acheson, frictional, injunction, mannerisms,
# Nearest to bible: depravity, eclectic, logie, exterminate, teleplay, circassians, mrnas, emulating,
# Nearest to gold: enrico, seeing, collaboratively, frauds, gib, harm, advent, seleucids,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4855 0.0295 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5000 0.0283 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4834 0.0283 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5150 0.0284 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4701 0.0283 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4715 0.0283 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4698 0.0283 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3704 0.0282 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4202 0.0284 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4243 0.0283 sec/batch
# Nearest to may: delicacy, adorned, drugs, displacement, codes, memes, stencils, crt,
# Nearest to in: trending, linguistic, interprets, remarkably, grocer, monism, internally, cutoff,
# Nearest to i: sociolinguistic, defaced, reviews, bowling, collier, marcellus, vedic, longer,
# Nearest to known: overheard, fluorescent, sea, filter, procuring, derivable, well, currently,
# Nearest to often: cobol, analyze, coffea, chemicals, deny, logische, decimated, normalised,
# Nearest to can: cells, caravaggio, ink, whether, very, earth, cartridges, shreveport,
# Nearest to other: popperian, harwich, inner, mineralogy, duplicates, disused, rare, terming,
# Nearest to not: agonal, dye, mani, grief, enthroned, envisage, abbr, might,
# Nearest to defense: equids, safavid, olives, hearse, going, oncology, principate, ajaigarh,
# Nearest to derived: faxes, humourous, copernican, smoked, politicized, cellulose, telstra, mpls,
# Nearest to hit: image, rained, pedersen, kano, condensed, viola, sherry, bothered,
# Nearest to liberal: election, elections, vertebra, overseen, eduke, suffrage, alves, political,
# Nearest to square: better, trouble, tm, leaven, nk, schematic, dalhousie, between,
# Nearest to heavy: sato, venter, chuppah, shutting, naphtali, acheson, mannerisms, shou,
# Nearest to bible: biblical, depravity, eclectic, ecumenical, circassians, exterminate, blanche, emulating,
# Nearest to gold: enrico, seeing, collaboratively, frauds, gib, seleucids, lz, harm,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4476 0.0294 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4028 0.0283 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4372 0.0284 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3785 0.0285 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4106 0.0284 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4448 0.0285 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3830 0.0284 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4016 0.0282 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4408 0.0283 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3620 0.0283 sec/batch
# Nearest to may: adorned, stencils, codes, delicacy, drugs, displacement, wheel, crt,
# Nearest to in: trending, southerners, grocer, middle, interprets, spouts, linguistic, intentions,
# Nearest to i: sociolinguistic, reviews, itch, marcellus, collier, defaced, canseco, vedic,
# Nearest to known: fluorescent, overheard, sea, bamboo, well, macias, hillsdale, derivable,
# Nearest to often: cobol, analyze, coffea, chemicals, normalised, outages, deny, triumphal,
# Nearest to can: cells, ink, whether, caravaggio, shreveport, waves, cartridges, snap,
# Nearest to other: popperian, harwich, inner, mineralogy, duplicates, barbarous, rare, schoolboy,
# Nearest to not: mani, agonal, dye, grief, abbr, might, enthroned, confuse,
# Nearest to defense: equids, safavid, principate, hearse, ajaigarh, olives, minoru, overruled,
# Nearest to derived: copernican, faxes, humourous, politicized, smoked, hagerstown, cellulose, wept,
# Nearest to hit: image, rained, viola, shots, pedersen, kano, sherry, condensed,
# Nearest to liberal: election, political, overseen, suffrage, elections, vertebra, payments, eduke,
# Nearest to square: trouble, better, tm, nk, leaven, schematic, dalhousie, aor,
# Nearest to heavy: sato, venter, chuppah, shutting, naphtali, acheson, mannerisms, exceeded,
# Nearest to bible: biblical, ecumenical, depravity, exterminate, eclectic, genesis, talmud, blanche,
# Nearest to gold: enrico, collaboratively, gib, seeing, frauds, seleucids, lz, pancake,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3647 0.0295 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4125 0.0283 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3550 0.0285 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3653 0.0284 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3847 0.0282 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3489 0.0284 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3640 0.0283 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3719 0.0283 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3486 0.0285 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3370 0.0282 sec/batch
# Nearest to may: stencils, codes, drugs, quenched, delicacy, adorned, dbm, macrophages,
# Nearest to in: disciplining, southerners, linguistic, ultimately, grocer, spouts, restrain, middle,
# Nearest to i: sociolinguistic, itch, reviews, timelike, vedic, marcellus, domains, collier,
# Nearest to known: fluorescent, sea, overheard, bamboo, saudis, macias, patricia, midrashic,
# Nearest to often: cobol, analyze, coffea, chemicals, logische, deny, normalised, decimated,
# Nearest to can: cells, ink, shreveport, caravaggio, whether, okina, inversely, slow,
# Nearest to other: popperian, inner, harwich, duplicates, barbarous, mineralogy, lured, rare,
# Nearest to not: dye, mani, agonal, grief, abbr, envisage, confuse, might,
# Nearest to defense: equids, safavid, troop, principate, hearse, turkmen, propounded, overruled,
# Nearest to derived: copernican, humourous, politicized, faxes, smoked, hagerstown, wept, unearthed,
# Nearest to hit: image, rained, shots, viola, bothered, kano, condensed, sherry,
# Nearest to liberal: election, suffrage, political, vertebra, overseen, elections, payments, peasants,
# Nearest to square: trouble, tm, nk, leaven, better, schematic, aor, dalhousie,
# Nearest to heavy: venter, sato, chuppah, shutting, surfaces, coldest, ammonium, bearing,
# Nearest to bible: biblical, ecumenical, depravity, exterminate, genesis, talmud, eclectic, chabad,
# Nearest to gold: enrico, collaboratively, gib, seeing, frauds, seleucids, pancake, weblogs,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3571 0.0294 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2930 0.0286 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3585 0.0283 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3959 0.0284 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3802 0.0281 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2921 0.0284 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3110 0.0282 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3428 0.0280 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2381 0.0284 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2903 0.0283 sec/batch
# Nearest to may: stencils, codes, dbm, delicacy, adorned, memorized, macrophages, drugs,
# Nearest to in: pearls, trending, elul, interrelationships, venting, ultimately, southerners, spouts,
# Nearest to i: sociolinguistic, marcellus, collier, itch, canseco, reviews, timelike, domains,
# Nearest to known: fluorescent, sea, overheard, bishkek, saudis, currently, macias, bamboo,
# Nearest to often: cobol, analyze, coffea, chemicals, normalised, ecsc, logische, pinker,
# Nearest to can: cells, ink, deallocated, caravaggio, whether, shreveport, okina, inversely,
# Nearest to other: popperian, inner, harwich, duplicates, mineralogy, lured, insignificance, stupa,
# Nearest to not: dye, mani, agonal, might, grief, does, frankland, confuse,
# Nearest to defense: equids, safavid, troop, principate, hearse, knicks, terrorist, without,
# Nearest to derived: copernican, humourous, politicized, faxes, unearthed, hagerstown, smoked, originates,
# Nearest to hit: image, shots, rained, viola, studio, chayefsky, bothered, sherry,
# Nearest to liberal: suffrage, vertebra, election, prof, overseen, political, payments, radical,
# Nearest to square: nk, trouble, tm, mosig, dalhousie, aor, leaven, schematic,
# Nearest to heavy: venter, sato, shutting, chuppah, lucky, mesothelioma, coldest, bearing,
# Nearest to bible: biblical, genesis, ecumenical, depravity, talmud, chabad, eclectic, exterminate,
# Nearest to gold: enrico, collaboratively, gib, seeing, frauds, pancake, koreans, seleucids,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2700 0.0294 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3224 0.0283 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3203 0.0126 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2433 0.0283 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2500 0.0284 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2341 0.0285 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2361 0.0282 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1681 0.0283 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2223 0.0283 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1979 0.0282 sec/batch
# Nearest to may: stencils, codes, dbm, delicacy, drugs, adorned, memorized, opencores,
# Nearest to in: trending, southerners, ultimately, spouts, elul, interrelationships, venting, densest,
# Nearest to i: marcellus, collier, sociolinguistic, itch, reigned, canseco, theurgy, timelike,
# Nearest to known: fluorescent, sea, bishkek, overheard, bamboo, macias, currently, saudis,
# Nearest to often: cobol, analyze, coffea, normalised, triumphal, pinker, shudo, ecsc,
# Nearest to can: deallocated, shreveport, cells, ink, caravaggio, arrestor, okina, waves,
# Nearest to other: popperian, inner, harwich, duplicates, mineralogy, stupa, insignificance, lured,
# Nearest to not: dye, mani, regularized, does, grief, agonal, confuse, frankland,
# Nearest to defense: equids, troop, terrorist, safavid, overruled, without, knicks, principate,
# Nearest to derived: humourous, copernican, faxes, originates, hagerstown, smoked, unearthed, politicized,
# Nearest to hit: image, shots, viola, rained, inning, bothered, massively, chayefsky,
# Nearest to liberal: suffrage, prof, payments, overseen, radical, election, vertebra, heterosexism,
# Nearest to square: tm, nk, dalhousie, trouble, mosig, aor, metropolitan, area,
# Nearest to heavy: venter, sato, tank, shutting, chuppah, mesothelioma, lucky, atgm,
# Nearest to bible: biblical, genesis, depravity, ecumenical, talmud, chabad, eclectic, exterminate,
# Nearest to gold: enrico, collaboratively, gib, seeing, frauds, pancake, seleucids, koreans,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2461 0.0294 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2546 0.0283 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2037 0.0283 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1091 0.0282 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1460 0.0284 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1931 0.0282 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1885 0.0284 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2048 0.0283 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1959 0.0283 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1725 0.0284 sec/batch
# Nearest to may: stencils, codes, dbm, drugs, memorized, delicacy, macrophages, adhesion,
# Nearest to in: spouts, ultimately, trending, interrelationships, venting, disciplining, susceptible, separating,
# Nearest to i: marcellus, domains, if, collier, you, itch, sociolinguistic, timelike,
# Nearest to known: fluorescent, bamboo, overheard, currently, saudis, bishkek, sea, procuring,
# Nearest to often: cobol, analyze, normalised, coffea, triumphal, pinker, shudo, ecsc,
# Nearest to can: deallocated, whether, ink, cells, shreveport, inversely, btu, conceptually,
# Nearest to other: popperian, inner, harwich, duplicates, mineralogy, insignificance, rare, stupa,
# Nearest to not: mani, does, evaluator, dye, confuse, agonal, option, might,
# Nearest to defense: equids, troop, terrorist, principate, overruled, knicks, safavid, without,
# Nearest to derived: copernican, originates, humourous, smoked, faxes, hagerstown, unearthed, benelux,
# Nearest to hit: shots, rained, image, inning, viola, bothered, massively, fired,
# Nearest to liberal: suffrage, prof, overseen, election, radical, heterosexism, elections, payments,
# Nearest to square: mosig, tm, nk, trouble, dalhousie, eastwards, aor, leaven,
# Nearest to heavy: sato, venter, tank, shutting, chuppah, mesothelioma, lucky, bearing,
# Nearest to bible: biblical, depravity, chabad, genesis, talmud, sufism, eclectic, embodied,
# Nearest to gold: enrico, pancake, frauds, collaboratively, seeing, bauxite, gib, koreans,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1783 0.0293 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2185 0.0283 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1820 0.0284 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1621 0.0282 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1611 0.0282 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1969 0.0284 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1924 0.0284 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1479 0.0281 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1316 0.0285 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1671 0.0284 sec/batch
# Nearest to may: stencils, codes, dbm, adorned, drugs, memorized, validity, delicacy,
# Nearest to in: spouts, interrelationships, spengler, ultimately, insurgent, densest, the, accord,
# Nearest to i: marcellus, domains, you, collier, if, canseco, itch, reigned,
# Nearest to known: fluorescent, overheard, saudis, macias, bamboo, bishkek, hillsdale, sea,
# Nearest to often: cobol, analyze, normalised, triumphal, equipment, pinker, shudo, coffea,
# Nearest to can: whether, inversely, deallocated, coppersmith, btu, ink, shreveport, conceptually,
# Nearest to other: popperian, inner, duplicates, insignificance, harwich, lured, mineralogy, stupa,
# Nearest to not: does, mani, frankland, converse, regularized, agonal, dye, confuse,
# Nearest to defense: equids, terrorist, troop, overruled, principate, minoru, safavid, knicks,
# Nearest to derived: copernican, humourous, smoked, unearthed, originates, faxes, hagerstown, waals,
# Nearest to hit: shots, rained, inning, viola, bothered, massively, image, eyesight,
# Nearest to liberal: suffrage, overseen, prof, heterosexism, radical, election, political, elections,
# Nearest to square: nk, tm, mosig, trouble, satisfying, schematic, aor, eastwards,
# Nearest to heavy: venter, sato, tank, shutting, chuppah, mesothelioma, atgm, lucky,
# Nearest to bible: biblical, chabad, depravity, genesis, annotations, eclectic, talmud, sufism,
# Nearest to gold: pancake, enrico, frauds, collaboratively, bauxite, seeing, gib, koreans,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2002 0.0294 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1661 0.0284 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1865 0.0283 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1867 0.0283 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1487 0.0283 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1524 0.0282 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1624 0.0283 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1341 0.0285 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1776 0.0287 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2283 0.0287 sec/batch
# Nearest to may: stencils, codes, declared, dbm, validity, celebrants, parma, memorized,
# Nearest to in: the, insurgent, spengler, knoxville, disciplining, interrelationships, standings, accord,
# Nearest to i: marcellus, you, domains, collier, reigned, jarrow, t, canseco,
# Nearest to known: overheard, bishkek, saudis, fluorescent, macias, sea, wagoner, bamboo,
# Nearest to often: cobol, analyze, triumphal, normalised, equipment, deontology, pinker, coffea,
# Nearest to can: deallocated, whether, shreveport, btu, inversely, hadza, coppersmith, ink,
# Nearest to other: popperian, lured, insignificance, inner, mineralogy, stupa, duplicates, spared,
# Nearest to not: mani, frankland, does, regularized, option, evaluator, dye, legislate,
# Nearest to defense: equids, terrorist, troop, overruled, lawrence, april, principate, knicks,
# Nearest to derived: unearthed, hagerstown, humourous, faxes, originates, copernican, smoked, politicized,
# Nearest to hit: shots, rained, inning, viola, kano, eyesight, massively, executioner,
# Nearest to liberal: prof, heterosexism, suffrage, overseen, political, radical, payments, eduke,
# Nearest to square: mosig, nk, trouble, tm, eastwards, schematic, dalhousie, appleseed,
# Nearest to heavy: sato, venter, shutting, tank, chuppah, atgm, mesothelioma, realised,
# Nearest to bible: biblical, genesis, chabad, depravity, annotations, eclectic, rcr, sufism,
# Nearest to gold: enrico, frauds, pancake, seeing, collaboratively, bauxite, gib, seleucids,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2405 0.0294 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1375 0.0284 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1458 0.0282 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1845 0.0283 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0597 0.0283 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1495 0.0284 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1465 0.0284 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1371 0.0283 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1683 0.0044 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1343 0.0284 sec/batch
# Nearest to may: stencils, codes, dbm, delicacy, celebrants, macrophages, drugs, gillette,
# Nearest to in: the, supercontinent, spouts, densest, resistors, interrelationships, first, standings,
# Nearest to i: marcellus, you, domains, t, if, jarrow, reigned, collier,
# Nearest to known: fluorescent, overheard, bishkek, saudis, sea, macias, restricted, bamboo,
# Nearest to often: cobol, analyze, normalised, triumphal, equipment, pinker, coffea, ecsc,
# Nearest to can: deallocated, ink, conceptually, coppersmith, caravaggio, btu, shreveport, whether,
# Nearest to other: popperian, inner, duplicates, mineralogy, lured, insignificance, stupa, harwich,
# Nearest to not: mani, evaluator, does, frankland, dye, regularized, option, bade,
# Nearest to defense: terrorist, equids, troop, overruled, april, knicks, lawrence, minoru,
# Nearest to derived: faxes, unearthed, originates, waals, hagerstown, humourous, copernican, tor,
# Nearest to hit: shots, rained, inning, kano, viola, simenon, martina, executioner,
# Nearest to liberal: heterosexism, prof, political, radical, overseen, niewyk, payments, eduke,
# Nearest to square: nk, mosig, trouble, tm, gondwana, schematic, area, dalhousie,
# Nearest to heavy: sato, venter, chuppah, tank, shutting, atgm, mesothelioma, calves,
# Nearest to bible: biblical, genesis, chabad, depravity, eclectic, sufism, annotations, tanakh,
# Nearest to gold: enrico, pancake, frauds, collaboratively, bauxite, blackouts, seeing, carloman,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0809 0.0294 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0872 0.0284 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0865 0.0283 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0573 0.0283 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0796 0.0285 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0548 0.0286 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0862 0.0283 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0883 0.0285 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1234 0.0286 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0416 0.0284 sec/batch
# Nearest to may: stencils, codes, dbm, delicacy, drugs, celebrants, macrophages, memorized,
# Nearest to in: the, spouts, standings, resistors, supercontinent, first, interrelationships, accord,
# Nearest to i: marcellus, you, domains, reigned, collier, t, if, theurgy,
# Nearest to known: fluorescent, overheard, bishkek, saudis, macias, currently, bamboo, restricted,
# Nearest to often: cobol, analyze, triumphal, normalised, equipment, upsets, pinker, deontology,
# Nearest to can: deallocated, btu, ink, inversely, caravaggio, whether, arrestor, shreveport,
# Nearest to other: popperian, inner, mineralogy, duplicates, rare, lured, stupa, harwich,
# Nearest to not: mani, does, dye, regularized, evaluator, negligence, option, frankland,
# Nearest to defense: terrorist, troop, equids, april, overruled, takeoffs, without, knicks,
# Nearest to derived: waals, faxes, benelux, originates, unearthed, copernican, unpaired, humourous,
# Nearest to hit: inning, shots, rained, massively, fired, kano, bothered, martina,
# Nearest to liberal: political, heterosexism, overseen, radical, election, prof, niewyk, liberties,
# Nearest to square: nk, mosig, trouble, tm, gondwana, area, eastwards, satisfying,
# Nearest to heavy: sato, atgm, tank, shutting, venter, mesothelioma, chuppah, calves,
# Nearest to bible: biblical, genesis, chabad, tanakh, depravity, mechon, press, sufism,
# Nearest to gold: enrico, frauds, pancake, seeing, carloman, collaboratively, blackouts, bauxite,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0276 0.0294 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0260 0.0284 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0274 0.0282 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0344 0.0283 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0920 0.0285 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0331 0.0282 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0366 0.0282 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0979 0.0286 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0679 0.0290 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0454 0.0290 sec/batch
# Nearest to may: stencils, codes, dbm, packaging, macrophages, delicacy, opencores, adhesion,
# Nearest to in: the, which, spouts, interrelationships, quantized, resistors, first, densest,
# Nearest to i: you, t, marcellus, domains, if, say, saying, header,
# Nearest to known: fluorescent, restricted, currently, filter, overheard, saudis, bishkek, bamboo,
# Nearest to often: cobol, analyze, normalised, triumphal, equipment, pinker, deontology, consist,
# Nearest to can: deallocated, whether, btu, inversely, ink, conceptually, coppersmith, catabolic,
# Nearest to other: popperian, duplicates, inner, mineralogy, rare, insignificance, lured, harwich,
# Nearest to not: does, evaluator, regularized, mani, confuse, extensional, wants, frankland,
# Nearest to defense: terrorist, equids, troop, april, overruled, takeoffs, knicks, security,
# Nearest to derived: faxes, benelux, unearthed, waals, copernican, tor, originates, peculiar,
# Nearest to hit: shots, inning, rained, kano, executioner, eyesight, gagarin, martina,
# Nearest to liberal: heterosexism, political, niewyk, radical, overseen, prof, moravians, eduke,
# Nearest to square: nk, trouble, mosig, satisfying, schematic, appleseed, tm, area,
# Nearest to heavy: sato, atgm, tank, calves, venter, chuppah, mesothelioma, shutting,
# Nearest to bible: biblical, genesis, chabad, tanakh, press, depravity, mechon, esdras,
# Nearest to gold: frauds, pancake, enrico, carloman, blackouts, collaboratively, emeralds, seeing,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0522 0.0296 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0924 0.0283 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0539 0.0284 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0855 0.0283 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0952 0.0283 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0319 0.0283 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0694 0.0280 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0566 0.0283 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0828 0.0283 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0819 0.0282 sec/batch
# Nearest to may: stencils, codes, dbm, opencores, celebrants, delicacy, memorized, validity,
# Nearest to in: the, which, spouts, seers, previous, first, ultimately, a,
# Nearest to i: you, marcellus, t, domains, reigned, if, saying, header,
# Nearest to known: fluorescent, overheard, currently, saudis, bamboo, restricted, macias, conglomerates,
# Nearest to often: cobol, triumphal, analyze, normalised, deontology, equipment, lydian, shudo,
# Nearest to can: deallocated, whether, btu, ink, inversely, dactylic, hadza, conceptually,
# Nearest to other: popperian, lured, euroscepticism, duplicates, mineralogy, rare, inner, insignificance,
# Nearest to not: does, mani, dye, regularized, anatomical, confuse, evaluator, converse,
# Nearest to defense: terrorist, april, troop, overruled, equids, security, lawrence, takeoffs,
# Nearest to derived: faxes, tor, benelux, unearthed, originates, peculiar, ethnographic, waals,
# Nearest to hit: inning, shots, kano, rained, gagarin, ajiva, executioner, martina,
# Nearest to liberal: heterosexism, niewyk, political, prof, moravians, eduke, partido, overseen,
# Nearest to square: trouble, nk, mosig, satisfying, appleseed, plano, area, resents,
# Nearest to heavy: sato, atgm, calves, chuppah, tank, shutting, venter, mesothelioma,
# Nearest to bible: biblical, genesis, chabad, depravity, press, tanakh, mechon, annotations,
# Nearest to gold: frauds, enrico, pancake, emeralds, carloman, blackouts, gib, risky,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0376 0.0295 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0164 0.0284 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0297 0.0283 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0839 0.0286 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0655 0.0282 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1209 0.0284 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1077 0.0282 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0444 0.0282 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0275 0.0282 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0743 0.0282 sec/batch
# Nearest to may: codes, stencils, dbm, opencores, celebrants, declared, delicacy, validity,
# Nearest to in: the, which, spouts, supercontinent, a, first, resistors, interrelationships,
# Nearest to i: you, t, domains, say, if, marcellus, header, saying,
# Nearest to known: saudis, bishkek, currently, overheard, fluorescent, midrashic, vilayet, unclear,
# Nearest to often: cobol, analyze, deontology, normalised, triumphal, equipment, ethnicities, lydian,
# Nearest to can: deallocated, btu, inversely, ink, joules, conceptually, very, hadza,
# Nearest to other: duplicates, inner, popperian, mineralogy, lured, phonation, rare, euroscepticism,
# Nearest to not: does, mani, evaluator, anatomical, extensional, let, wants, negligence,
# Nearest to defense: terrorist, april, troop, equids, overruled, lawrence, gpu, security,
# Nearest to derived: faxes, tor, ethnographic, peculiar, unpaired, logographic, pyramids, originates,
# Nearest to hit: inning, kano, shots, executioner, gagarin, martina, rained, debut,
# Nearest to liberal: heterosexism, political, niewyk, prof, moravians, partido, diplodocus, eduke,
# Nearest to square: trouble, nk, mosig, area, appleseed, resents, plano, satisfying,
# Nearest to heavy: sato, atgm, calves, atgms, tank, chuppah, mesothelioma, venter,
# Nearest to bible: biblical, chabad, genesis, press, depravity, tanakh, primus, mechon,
# Nearest to gold: frauds, enrico, pancake, carloman, blackouts, emeralds, seeing, risky,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9977 0.0292 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0125 0.0284 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0392 0.0283 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0234 0.0283 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0891 0.0282 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0343 0.0245 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0364 0.0284 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9692 0.0284 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0193 0.0283 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9421 0.0282 sec/batch
# Nearest to may: stencils, codes, dbm, opencores, delicacy, macrophages, packaging, drugs,
# Nearest to in: the, which, first, spouts, resistors, a, as, where,
# Nearest to i: you, marcellus, t, reigned, say, domains, saying, shall,
# Nearest to known: fluorescent, currently, overheard, parnell, bishkek, saudis, conglomerates, macias,
# Nearest to often: cobol, analyze, normalised, triumphal, deontology, lydian, equipment, ethnicities,
# Nearest to can: deallocated, duplication, ink, conceptually, btu, whether, inversely, tends,
# Nearest to other: duplicates, inner, rare, popperian, mineralogy, phonation, lured, insignificance,
# Nearest to not: does, mani, anatomical, evaluator, extensional, converse, let, drinking,
# Nearest to defense: troop, april, takeoffs, terrorist, overruled, gpu, equids, lawrence,
# Nearest to derived: faxes, tor, peculiar, humourous, pyramids, benelux, waals, unearthed,
# Nearest to hit: kano, inning, shots, martina, executioner, lollapalooza, gagarin, simenon,
# Nearest to liberal: heterosexism, moravians, niewyk, diplodocus, prof, overseen, eduke, partido,
# Nearest to square: trouble, mosig, nk, appleseed, resents, area, plano, eastwards,
# Nearest to heavy: sato, atgm, atgms, calves, tank, mesothelioma, dickinson, naphtali,
# Nearest to bible: biblical, genesis, chabad, tanakh, depravity, press, mechon, decentralised,
# Nearest to gold: frauds, pancake, enrico, emeralds, risky, seeing, blackouts, carloman,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0246 0.0293 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9376 0.0285 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0268 0.0283 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0262 0.0286 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0149 0.0283 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0080 0.0283 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9238 0.0283 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9765 0.0286 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9495 0.0285 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9617 0.0283 sec/batch
# Nearest to may: stencils, codes, dbm, drugs, packaging, celebrants, opencores, administering,
# Nearest to in: the, which, a, first, for, and, as, previous,
# Nearest to i: you, t, say, domains, marcellus, header, want, shall,
# Nearest to known: fluorescent, currently, restricted, filter, bishkek, bamboo, parnell, unclear,
# Nearest to often: cobol, analyze, triumphal, normalised, deontology, ethnicities, equipment, trimeter,
# Nearest to can: deallocated, whether, conceptually, or, ink, okina, inversely, duplication,
# Nearest to other: mineralogy, duplicates, rare, inner, popperian, insignificance, harwich, lured,
# Nearest to not: does, let, extensional, anatomical, converse, mani, negligence, evaluator,
# Nearest to defense: troop, april, takeoffs, equids, lawrence, overruled, terrorist, intercept,
# Nearest to derived: benelux, peculiar, faxes, tor, waals, unrelated, humourous, landi,
# Nearest to hit: inning, lollapalooza, kano, charts, shots, gagarin, executioner, martina,
# Nearest to liberal: moravians, heterosexism, niewyk, eduke, partido, overseen, political, diplodocus,
# Nearest to square: trouble, nk, mosig, appleseed, plano, resents, area, pneumatic,
# Nearest to heavy: sato, atgm, atgms, dickinson, tank, calves, naphtali, mesothelioma,
# Nearest to bible: chabad, biblical, tanakh, genesis, ketuvim, press, mechon, depravity,
# Nearest to gold: frauds, pancake, enrico, emeralds, blackouts, seeing, carloman, drusilla,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0047 0.0294 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0113 0.0284 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9549 0.0284 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0098 0.0282 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0036 0.0282 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9609 0.0284 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9792 0.0283 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9750 0.0283 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9792 0.0283 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0025 0.0284 sec/batch
# Nearest to may: stencils, codes, dbm, celebrants, packaging, drugs, expires, administering,
# Nearest to in: the, which, first, a, for, previous, as, of,
# Nearest to i: you, t, say, header, domains, want, know, marcellus,
# Nearest to known: currently, fluorescent, parnell, unclear, overheard, conglomerates, restricted, bishkek,
# Nearest to often: analyze, equipment, cobol, ethnicities, normalised, trimeter, lydian, triumphal,
# Nearest to can: whether, deallocated, conceptually, btu, or, okina, coppersmith, voters,
# Nearest to other: duplicates, rare, mineralogy, inner, gait, popperian, insignificance, lured,
# Nearest to not: does, let, it, would, extensional, anatomical, converse, but,
# Nearest to defense: april, lawrence, takeoffs, equids, troop, bacteriologist, knicks, biostatistics,
# Nearest to derived: benelux, tor, faxes, peculiar, humourous, waals, landi, ethnographic,
# Nearest to hit: charts, lollapalooza, kano, executioner, inning, gagarin, martina, pedersen,
# Nearest to liberal: moravians, niewyk, eduke, heterosexism, partido, political, overseen, zwingli,
# Nearest to square: trouble, nk, appleseed, mosig, plano, resents, boundaries, monument,
# Nearest to heavy: sato, atgm, atgms, calves, tank, mesothelioma, shutting, dickinson,
# Nearest to bible: chabad, press, biblical, tanakh, genesis, ketuvim, mechon, depravity,
# Nearest to gold: frauds, pancake, enrico, emeralds, blackouts, carloman, poulsen, drusilla,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0116 0.0295 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9684 0.0283 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9564 0.0285 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9952 0.0283 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0167 0.0284 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9930 0.0284 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9884 0.0283 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9358 0.0283 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9681 0.0281 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0214 0.0284 sec/batch
# Nearest to may: stencils, codes, dbm, blindly, validity, procedural, clause, expires,
# Nearest to in: the, which, as, and, first, for, of, a,
# Nearest to i: you, t, header, say, domains, want, shall, know,
# Nearest to known: currently, unclear, restricted, vilayet, fluorescent, conglomerates, parnell, switched,
# Nearest to often: analyze, equipment, deontology, ethnicities, lydian, cobol, trimeter, normalised,
# Nearest to can: deallocated, btu, conceptually, ink, joules, or, inversely, very,
# Nearest to other: insignificance, duplicates, euroscepticism, rare, are, inner, lured, popperian,
# Nearest to not: does, would, let, it, regularized, but, negligence, wants,
# Nearest to defense: april, lawrence, equids, troop, biostatistics, takeoffs, grappling, gpu,
# Nearest to derived: peculiar, tor, faxes, benelux, humourous, class, essentially, waals,
# Nearest to hit: lollapalooza, kano, charts, inning, executioner, gagarin, atmospheres, martina,
# Nearest to liberal: moravians, niewyk, partido, eduke, heterosexism, overseen, radical, prof,
# Nearest to square: trouble, nk, appleseed, mosig, resents, plano, area, boundaries,
# Nearest to heavy: sato, atgm, atgms, calves, tank, azeglio, dickinson, shutting,
# Nearest to bible: chabad, biblical, genesis, tanakh, ketuvim, press, depravity, mechon,
# Nearest to gold: frauds, pancake, enrico, emeralds, retrospect, silver, risky, carloman,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9671 0.0297 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0870 0.0283 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0093 0.0284 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0430 0.0282 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9722 0.0284 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9554 0.0281 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8076 0.0288 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8107 0.0289 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8415 0.0290 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8786 0.0293 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8211 0.0287 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8698 0.0289 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9275 0.0289 sec/batch
# Nearest to may: associated, packaging, or, however, days, for, administering, be,
# Nearest to in: the, for, a, as, and, of, which, an,
# Nearest to i: you, t, know, am, say, so, want, thank,
# Nearest to known: currently, unclear, the, most, as, by, switched, promising,
# Nearest to often: equipment, use, trimeter, deontology, especially, barbed, fluoresce, and,
# Nearest to can: deallocated, or, make, controllable, use, ink, not, only,
# Nearest to other: are, and, all, such, still, for, these, there,
# Nearest to not: but, would, the, does, that, it, to, in,
# Nearest to defense: grappling, backfield, nato, abm, defence, aerospace, western, bans,
# Nearest to derived: peculiar, tor, faxes, kotorska, class, landi, essentially, inari,
# Nearest to hit: lollapalooza, charts, hits, kano, billboard, outflows, royalties, pedersen,
# Nearest to liberal: partido, improvised, moravians, diplodocus, doraemon, politics, fatale, democrat,
# Nearest to square: trouble, area, appleseed, boundaries, resents, monument, roughly, mosig,
# Nearest to heavy: sato, atgm, atgms, syncopation, dickinson, dri, treadmill, z,
# Nearest to bible: chabad, tanakh, ketuvim, whitmore, biblical, press, decentralised, genesis,
# Nearest to gold: silver, frauds, emeralds, drusilla, bauxite, poulsen, copper, legend,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8356 0.0299 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8388 0.0290 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8578 0.0290 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8352 0.0289 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8588 0.0289 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8801 0.0289 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8428 0.0288 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8478 0.0288 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8782 0.0286 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8618 0.0289 sec/batch
# Nearest to may: associated, however, packaging, days, or, be, for, blindly,
# Nearest to in: the, for, a, as, of, which, and, an,
# Nearest to i: you, know, t, am, say, so, thank, what,
# Nearest to known: unclear, currently, the, by, goddard, as, most, switched,
# Nearest to often: equipment, trimeter, especially, use, lydian, deontology, most, pasquale,
# Nearest to can: very, deallocated, or, only, tends, ink, voters, conceptually,
# Nearest to other: are, and, all, such, still, both, there, for,
# Nearest to not: but, the, would, that, to, it, in, does,
# Nearest to defense: grappling, nato, defence, abm, backfield, aerospace, biostatistics, apparatus,
# Nearest to derived: peculiar, tor, faxes, kotorska, class, essentially, inari, landi,
# Nearest to hit: lollapalooza, charts, hits, billboard, royalties, outflows, kano, biggest,
# Nearest to liberal: partido, fatale, improvised, moravians, democrat, doraemon, diplodocus, politics,
# Nearest to square: trouble, boundaries, area, resents, appleseed, monument, kilometers, roughly,
# Nearest to heavy: sato, atgm, atgms, syncopation, nevertheless, treadmill, dri, z,
# Nearest to bible: chabad, tanakh, whitmore, ketuvim, redding, genesis, sumerians, biblical,
# Nearest to gold: silver, frauds, emeralds, bauxite, precious, copper, drusilla, brightly,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8567 0.0300 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8692 0.0289 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8277 0.0289 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8443 0.0288 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8783 0.0290 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8629 0.0290 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9741 0.0288 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9292 0.0287 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9394 0.0288 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8398 0.0288 sec/batch
# Nearest to may: days, be, is, for, packaging, associated, or, however,
# Nearest to in: the, for, and, a, as, of, which, an,
# Nearest to i: you, know, t, so, say, am, want, thank,
# Nearest to known: unclear, currently, the, most, by, as, is, promising,
# Nearest to often: equipment, especially, use, deontology, lydian, trimeter, usually, pasquale,
# Nearest to can: deallocated, very, only, or, controllable, irregulars, lindh, conceptually,
# Nearest to other: are, and, all, such, these, there, both, still,
# Nearest to not: would, but, does, that, it, the, to, those,
# Nearest to defense: grappling, nato, defence, apparatus, backfield, aerospace, bacteriologist, abm,
# Nearest to derived: peculiar, tor, faxes, kotorska, class, therefore, inari, essentially,
# Nearest to hit: lollapalooza, charts, hits, bombay, kano, outflows, royalties, pedersen,
# Nearest to liberal: partido, democrat, improvised, fatale, moravians, politics, diplodocus, doraemon,
# Nearest to square: trouble, area, boundaries, appleseed, resents, monument, kilometers, roughly,
# Nearest to heavy: sato, atgm, atgms, syncopation, fearless, dri, tek, treadmill,
# Nearest to bible: chabad, ketuvim, tanakh, redding, whitmore, biblical, fishery, sumerians,
# Nearest to gold: silver, frauds, emeralds, precious, bauxite, drusilla, copper, brightly,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7981 0.0299 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8257 0.0288 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8000 0.0290 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8797 0.0288 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8746 0.0288 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8369 0.0288 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9168 0.0122 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8328 0.0291 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8283 0.0287 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8165 0.0288 sec/batch
# Nearest to may: days, associated, is, packaging, april, or, for, administering,
# Nearest to in: the, for, a, of, as, and, which, an,
# Nearest to i: you, know, t, am, so, say, what, dux,
# Nearest to known: the, currently, unclear, most, by, promising, as, well,
# Nearest to often: especially, equipment, use, trimeter, deontology, pasquale, ditko, metrication,
# Nearest to can: deallocated, controllable, jamison, irregulars, very, unpleasantly, ink, conceptually,
# Nearest to other: are, and, all, such, these, still, bai, both,
# Nearest to not: but, would, that, does, the, to, those, it,
# Nearest to defense: grappling, backfield, nato, defence, abm, apparatus, bans, aerospace,
# Nearest to derived: peculiar, tor, kotorska, faxes, ethnographic, word, class, derivation,
# Nearest to hit: lollapalooza, charts, hits, pedersen, billboard, royalties, bombay, outflows,
# Nearest to liberal: partido, fatale, improvised, democrat, politics, moravians, diplodocus, fascists,
# Nearest to square: trouble, area, appleseed, boundaries, resents, monument, kilometers, roughly,
# Nearest to heavy: sato, atgm, atgms, syncopation, tek, z, dri, treadmill,
# Nearest to bible: chabad, whitmore, ketuvim, tanakh, redding, biblical, curdling, sumerians,
# Nearest to gold: silver, frauds, emeralds, precious, drusilla, legend, brightly, bauxite,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8369 0.0298 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8113 0.0286 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8398 0.0288 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7682 0.0287 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8481 0.0289 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8615 0.0288 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8733 0.0287 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7633 0.0287 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7836 0.0288 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8334 0.0287 sec/batch
# Nearest to may: associated, days, or, packaging, for, administering, however, april,
# Nearest to in: the, for, a, of, as, and, which, an,
# Nearest to i: you, t, so, know, am, say, what, want,
# Nearest to known: the, currently, unclear, as, most, by, promising, of,
# Nearest to often: trimeter, use, deontology, ditko, equipment, especially, other, referred,
# Nearest to can: be, or, deallocated, is, not, only, cannot, point,
# Nearest to other: are, and, all, such, by, there, both, these,
# Nearest to not: but, does, the, would, that, it, to, be,
# Nearest to defense: grappling, backfield, nato, defence, abm, aerospace, bacteriologist, western,
# Nearest to derived: peculiar, tor, kotorska, faxes, and, essentially, class, ethnographic,
# Nearest to hit: lollapalooza, charts, hits, billboard, biggest, bombay, pedersen, outflows,
# Nearest to liberal: democrat, partido, improvised, diplodocus, election, fatale, doraemon, politics,
# Nearest to square: area, trouble, boundaries, appleseed, monument, roughly, kilometers, a,
# Nearest to heavy: sato, atgm, atgms, syncopation, z, tek, dri, treadmill,
# Nearest to bible: chabad, ketuvim, biblical, tanakh, whitmore, forme, vulgate, genesis,
# Nearest to gold: silver, frauds, emeralds, drusilla, copper, precious, bauxite, brightly,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7549 0.0295 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8138 0.0287 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8608 0.0285 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8203 0.0286 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8297 0.0284 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8935 0.0287 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8395 0.0287 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8252 0.0284 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8394 0.0285 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8328 0.0287 sec/batch
# Nearest to may: for, associated, or, packaging, however, be, days, is,
# Nearest to in: the, for, of, a, as, and, which, an,
# Nearest to i: you, t, know, am, so, thank, say, header,
# Nearest to known: the, unclear, currently, as, most, promising, by, used,
# Nearest to often: especially, other, use, trimeter, in, an, referred, equipment,
# Nearest to can: not, or, very, make, deallocated, is, use, only,
# Nearest to other: are, all, and, such, for, by, both, the,
# Nearest to not: but, the, does, that, would, to, it, those,
# Nearest to defense: grappling, defence, backfield, nato, aerospace, biostatistics, viridis, western,
# Nearest to derived: peculiar, tor, kotorska, faxes, class, essentially, restricting, ethnographic,
# Nearest to hit: lollapalooza, charts, hits, billboard, biggest, pedersen, carl, bombay,
# Nearest to liberal: democrat, partido, improvised, diplodocus, election, fatale, politics, conservative,
# Nearest to square: trouble, boundaries, area, appleseed, resents, roughly, monument, mosig,
# Nearest to heavy: sato, atgm, atgms, z, syncopation, treadmill, tek, mannerisms,
# Nearest to bible: chabad, biblical, ketuvim, whitmore, tanakh, forme, embodied, redding,
# Nearest to gold: silver, frauds, emeralds, drusilla, poulsen, precious, bauxite, copper,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8689 0.0296 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8384 0.0286 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8082 0.0288 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8564 0.0288 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8163 0.0286 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8481 0.0288 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8318 0.0286 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8459 0.0289 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8101 0.0286 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8265 0.0286 sec/batch
# Nearest to may: for, is, or, however, be, associated, this, days,
# Nearest to in: the, and, for, a, of, as, which, an,
# Nearest to i: you, t, am, know, so, thank, want, say,
# Nearest to known: the, currently, unclear, most, by, used, of, as,
# Nearest to often: especially, other, trimeter, usually, an, equipment, this, use,
# Nearest to can: or, not, only, very, be, deallocated, make, is,
# Nearest to other: are, all, and, such, the, for, a, there,
# Nearest to not: but, it, the, would, does, that, for, in,
# Nearest to defense: grappling, nato, backfield, defence, biostatistics, apparatus, aerospace, western,
# Nearest to derived: peculiar, kotorska, tor, and, essentially, class, bulgarians, faxes,
# Nearest to hit: lollapalooza, hits, charts, billboard, biggest, outflows, bombay, inning,
# Nearest to liberal: partido, democrat, improvised, diplodocus, fatale, election, politics, moravians,
# Nearest to square: trouble, boundaries, area, appleseed, resents, roughly, mosig, kilometers,
# Nearest to heavy: sato, atgm, atgms, treadmill, syncopation, z, dri, mannerisms,
# Nearest to bible: chabad, biblical, ketuvim, whitmore, tanakh, embodied, decentralised, forme,
# Nearest to gold: silver, frauds, emeralds, poulsen, drusilla, bauxite, copper, precious,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8450 0.0297 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8299 0.0288 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8981 0.0289 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9107 0.0287 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8745 0.0285 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8325 0.0289 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7772 0.0285 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8136 0.0285 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7174 0.0287 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8558 0.0287 sec/batch
# Nearest to may: for, is, days, or, associated, packaging, be, blindly,
# Nearest to in: the, for, and, a, of, as, an, is,
# Nearest to i: you, t, am, so, know, say, what, thank,
# Nearest to known: the, most, unclear, currently, many, used, include, as,
# Nearest to often: other, an, a, and, especially, usually, trimeter, equipment,
# Nearest to can: not, or, be, very, make, is, tends, deallocated,
# Nearest to other: are, and, all, such, by, the, a, both,
# Nearest to not: but, it, does, would, that, be, the, there,
# Nearest to defense: grappling, nato, defence, backfield, western, aerospace, apparatus, biostatistics,
# Nearest to derived: peculiar, kotorska, tor, essentially, class, jakob, faxes, word,
# Nearest to hit: lollapalooza, charts, biggest, hits, bombay, outflows, billboard, royalties,
# Nearest to liberal: democrat, diplodocus, fatale, partido, improvised, prof, moravians, politics,
# Nearest to square: trouble, boundaries, area, appleseed, resents, kilometers, monument, leaven,
# Nearest to heavy: sato, atgm, atgms, treadmill, mannerisms, syncopation, tek, dri,
# Nearest to bible: chabad, biblical, tanakh, whitmore, ketuvim, forme, sumerians, fishery,
# Nearest to gold: silver, frauds, emeralds, copper, bauxite, drusilla, precious, poulsen,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8549 0.0296 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8344 0.0284 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
